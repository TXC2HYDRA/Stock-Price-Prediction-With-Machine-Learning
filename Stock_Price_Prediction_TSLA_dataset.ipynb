# %%
# !pip3 install chart_studio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly .offline import plot
import tensorflow as tf

from plotly.offline import download_plotlyjs , init_notebook_mode , plot , iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = https://www.kaggle.com/datasets/timoboz/tesla-stock-data-from-2010-to-2020/data?select=TSLA.csv

#this data set is used in this Project
# Out:
#   File "<ipython-input-51-9b019f9583be>", line 1
#     url = https://www.kaggle.com/datasets/timoboz/tesla-stock-data-from-2010-to-2020/data?select=TSLA.csv
#                ^
# SyntaxError: invalid syntax

# %%
tesla = pd.read_csv('/content/TSLA.csv')
tesla.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tesla.info()
tesla.isnull().sum()
tesla.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416 entries, 0 to 2415
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2416 non-null   object
#  1   Open       2416 non-null   float64
#  2   High       2416 non-null   float64
#  3   Low        2416 non-null   float64
#  4   Close      2416 non-null   float64
#  5   Adj Close  2416 non-null   float64
#  6   Volume     2416 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 132.2+ KB
#               Open         High          Low        Close    Adj Close  \
# count  2416.000000  2416.000000  2416.000000  2416.000000  2416.000000
# mean    186.271147   189.578224   182.916639   186.403651   186.403651
# std     118.740163   120.892329   116.857591   119.136020   119.136020
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      34.342498    34.897501    33.587501    34.400002    34.400002
# ...

# %%
tesla['Date'] = pd.to_datetime(tesla['Date'])

# %%
print(f'DataFrame contains stock data between {tesla.Date.min()} and {tesla.Date.max()}.')
print(f'Total Days = {(tesla.Date.max() - tesla.Date.min()).days} Days')
# Out:
# DataFrame contains stock data between 2010-06-29 00:00:00 and 2020-02-03 00:00:00.
# Total Days = 3506 Days

# %%
# Create the line chart trace
fig = go.Figure(data=go.Scatter(x=tesla['Date'], y=tesla['Close'], mode='lines'))

# Update layout with the specified options
fig.update_layout(
    title='Stock Prices of Tesla',
    xaxis=dict(
        title='Date',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Price',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)

fig.show()
# Out:
# <div>                            <div id="fa3479ca-8eee-45f1-9c03-da3a103219f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa3479ca-8eee-45f1-9c03-da3a103219f8")) {                    Plotly.newPlot(                        "fa3479ca-8eee-45f1-9c03-da3a103219f8",                        [{"mode":"lines","x":["2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-
# ...

# %%
#Building a Regression model
from sklearn.model_selection import train_test_split

#For Preprocessing
from sklearn.preprocessing import MinMaxScaler , StandardScaler

#For model Evavluation
from sklearn.metrics import mean_squared_error as mse , r2_score

# %%
#Split data into Train and Test

X = np.array(tesla.index).reshape(-1,1)
Y = tesla['Close']

X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size = 0.3 , random_state = 101)

# %%
#Feature Scaling
scaler = StandardScaler().fit(X_train)

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
#Creating a Linear Regression Model

lm = LR()
lm.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
trace0 = go.Scatter(
    x = X_train.T[0],
    y = Y_train,
    mode = 'markers',
    name = 'Actual'
)
trace1 = go.Scatter(
     x = X_train.T[0],
     y = lm.predict(X_train).T,
     mode = 'lines',
     name = 'Predicted'
)

tesla_data = [trace0,trace1]
layout.xaxis.title.text = 'Day'
plot2 = go.Figure(data=tesla_data , layout = layout)

# %%
iplot(plot2)
# Out:
# <div>                            <div id="63f6ce80-7bcb-42ce-86e5-a4c13cabd54e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63f6ce80-7bcb-42ce-86e5-a4c13cabd54e")) {                    Plotly.newPlot(                        "63f6ce80-7bcb-42ce-86e5-a4c13cabd54e",                        [{"mode":"markers","name":"Actual","x":[1240,2360,32,242,1396,1519,2035,134,54,1261,585,1473,1307,1116,1678,1838,569,747,110,884,928,1097,844,1158,2123,1911,230,366,1159,258,1280,976,1059,690,422,342,1526,1921,1893,1325,1848,2066,1123,1510,1079,2396,1147,1756,1934,1771,1907,404,1675,2343,2345,2106,1689,731,1430,922,1131,1712,969,1706,429,1687,758,2191,1696,92,1395,669,1798,1612,146,221,353,708,492,643,284,454,466,490,925,62,52,1499,534,1054,756,1996,1016,1587,1420
# ...

# %%
scores = f'''
{'Metric'.ljust(10)}{'Train'.center(20)}{'Test'.center(20)}
{'r2_score'.ljust(10)}{r2_score(Y_train , lm.predict(X_train))}\t{r2_score(Y_test , lm.predict(X_test))}
{'MSE'.ljust(10)}{mse(Y_train , lm.predict(X_train))}\t{mse(Y_test , lm.predict(X_test))}
'''
print(scores)
# Out:
# Metric           Train                Test
# r2_score  0.788228331751714	0.8024543287892049
# MSE       3018.796360995388	2768.704187535219
